# %%
import joblib
import numpy as np
import pandas as pd
artifact = joblib.load("svm_model.joblib")
svm_model = artifact["model"]
best_thr = artifact["threshold"]

# %%
df = pd.read_excell("Testdata.xls")
df = df.drop("ID", axis=1)

# %%
scores_new = best_svm_final.decision_function(df)
y_new_pred = (scores_new >= best_thr).astype(int)
